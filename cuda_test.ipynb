# %%
import torch

print(f"¿CUDA disponible?: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU detectada: {torch.cuda.get_device_name(0)}")
    
    tensor_prueba = torch.rand(3, 3).cuda()
    print("\nTensor creado exitosamente en la VRAM:")
    print(tensor_prueba)
else:
    print("\nCUDA no está disponible. PyTorch está usando el CPU.")
# Out:
# ¿CUDA disponible?: True
# GPU detectada: NVIDIA GeForce RTX 3060 Laptop GPU
#
# Tensor creado exitosamente en la VRAM:
# tensor([[0.0266, 0.8399, 0.8919],
#         [0.9861, 0.8308, 0.6758],
#         [0.6974, 0.7028, 0.1806]], device='cuda:0')
